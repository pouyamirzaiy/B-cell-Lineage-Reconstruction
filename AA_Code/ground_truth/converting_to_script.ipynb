# %%
# !jupyter nbconvert --to script BasicSeq.ipynb
# Out:
# [NbConvertApp] Converting notebook BasicSeq.ipynb to script
# [NbConvertApp] Writing 4093 bytes to BasicSeq.py

# %%
# !jupyter nbconvert --to script BasicTree.ipynb
# Out:
# [NbConvertApp] Converting notebook BasicTree.ipynb to script
# [NbConvertApp] Writing 7477 bytes to BasicTree.py

# %%
# !jupyter nbconvert --to script MSTree.ipynb
# Out:
# [NbConvertApp] Converting notebook MSTree.ipynb to script
# [NbConvertApp] Writing 3454 bytes to MSTree.py
