# %%
import os

folder = r"C:\Users\LEGION\Downloads\modify\modified\LLC"

for root, dirs, files in os.walk(folder):
    print(" Folder:", root)
    for f in files:
        print("   -", f)
# Out:
#  Folder: C:\Users\LEGION\Downloads\modify\modified\LLC
#    - .DS_Store
#    - ALL_LLC_clean.fa
#    - ALL_LLC_concatenated.fa
#    - LLC_dataset01_1_200
#    - LLC_dataset01_1_200.csv
#    - LLC_dataset01_1_200_sequences.aln.fa
#    - LLC_dataset01_1_200_sequences.aln.fa.nk
#    - LLC_dataset02_1_200
#    - LLC_dataset02_1_200.csv
#    - LLC_dataset02_1_200_sequences.aln.fa
#    - LLC_dataset02_1_200_sequences.aln.fa.nk
#    - LLC_dataset03_1_200
#    - LLC_dataset03_1_200.csv
#    - LLC_dataset03_1_200_sequences.aln.fa
#    - LLC_dataset03_1_200_sequences.aln.fa.nk
#    - LLC_dataset04_1_200
#    - LLC_dataset04_1_200.csv
#    - LLC_dataset04_1_200_sequences.aln.fa
#    - LLC_dataset04_1_200_sequences.aln.fa.nk
#    - LLC_dataset05_1_200
#    - LLC_dataset05_1_200.csv
#    - LLC_dataset05_1_200_sequences.aln.fa
#    - LLC_dataset05_1_200_sequences.aln.fa.nk
#    - LLC_dataset06_1_200
#    - LLC_dataset06_1_200.csv
#    - LLC_dataset06_1_200_sequences.aln.fa
# ...
