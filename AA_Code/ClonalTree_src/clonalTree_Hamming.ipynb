# %%
import numpy as np
from MSTree import primMST
from BasicTree import trimming, editTree, getDistances
from BasicSeq import readFastaAbundance, createAdjMatrix

def run_clonalTree_aa(
    inputFile,
    outputFile,
    useAbundance=True,
    revision=True,
    trim=True
):
    """
    Jupyter-friendly AA-Hamming ClonalTree runner.
    No command-line arguments. No OptionParser.
    """

    print("Running AA-Hamming ClonalTree")
    print("Input FASTA:", inputFile)
    print("Output:", outputFile)
    print("Settings → useAbundance:", useAbundance,
          "; revision:", revision, "; trim:", trim)

    #---------------------------------------------------------
    # 1. Read AA sequences + abundance
    #---------------------------------------------------------
    labels, root, arraySeqs, abundance, _ = readFastaAbundance(inputFile)

    print(f"Found {len(labels)} sequences")
    print(f"Root sequence: {labels[root]}")
    print(f"Abundance range: {min(abundance.values())} to {max(abundance.values())}")

    #---------------------------------------------------------
    # 2. Create adjacency matrix using AA Hamming distance
    #---------------------------------------------------------
    adjMatrix = createAdjMatrix(arraySeqs)

    print("Building MST tree...")

    #---------------------------------------------------------
    # 3. Build MST tree
    #---------------------------------------------------------
    tree, infoTree = primMST(adjMatrix, root, labels, abundance, useAbundance)

    #---------------------------------------------------------
    # 4. Optional trimming and revision
    #---------------------------------------------------------
    if trim:
        print("Trimming tree...")
        tree = trimming(tree, labels, adjMatrix)

    if revision:
        print("Revising tree...")
        tree = editTree(tree, adjMatrix, labels)

    #---------------------------------------------------------
    # 5. Export results
    #---------------------------------------------------------
    infoTree = getDistances(tree)

    tree.write(format=1, outfile=outputFile)
    with open(outputFile + ".csv", "w") as f:
        f.write(infoTree)

    print("Done!")
    print("Tree saved to:", outputFile)
    print("CSV saved to:", outputFile + ".csv")

    return tree

# %%
import os

input_dir = r"C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA"

for file in os.listdir(input_dir):

    if file.endswith(".fa"):

        input_path = os.path.join(input_dir, file)

        output_path = os.path.join(
            input_dir,
            file.replace(".fa", ".nk")
        )

        run_clonalTree_aa(
            inputFile=input_path,
            outputFile=output_path,
            useAbundance=True,
            revision=True,
            trim=True
        )

        print(f"Done: {file}")
# Out:
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset01_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset01_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 34 sequences
# Root sequence: naive
# Abundance range: 1 to 50042
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset01_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset01_1_200_AA.nk.csv
# Done: LLC_dataset01_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset02_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset02_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 41 sequences
# Root sequence: naive
# Abundance range: 1 to 281852
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset02_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset02_1_200_AA.nk.csv
# Done: LLC_dataset02_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset03_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset03_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 19 sequences
# Root sequence: naive
# Abundance range: 1 to 21382
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset03_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset03_1_200_AA.nk.csv
# Done: LLC_dataset03_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset04_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset04_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 69 sequences
# Root sequence: naive
# Abundance range: 1 to 32545
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset04_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset04_1_200_AA.nk.csv
# Done: LLC_dataset04_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset05_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset05_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 36 sequences
# Root sequence: naive
# Abundance range: 1 to 45776
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset05_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset05_1_200_AA.nk.csv
# Done: LLC_dataset05_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset06_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset06_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 44 sequences
# Root sequence: naive
# Abundance range: 1 to 11048
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset06_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset06_1_200_AA.nk.csv
# Done: LLC_dataset06_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset07_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset07_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 69 sequences
# Root sequence: naive
# Abundance range: 1 to 19812
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset07_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset07_1_200_AA.nk.csv
# Done: LLC_dataset07_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset08_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset08_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 81 sequences
# Root sequence: naive
# Abundance range: 1 to 91465
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset08_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset08_1_200_AA.nk.csv
# Done: LLC_dataset08_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset09_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset09_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 10 sequences
# Root sequence: naive
# Abundance range: 1 to 33248
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset09_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset09_1_200_AA.nk.csv
# Done: LLC_dataset09_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset10_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset10_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 24 sequences
# Root sequence: naive
# Abundance range: 1 to 82058
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset10_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset10_1_200_AA.nk.csv
# Done: LLC_dataset10_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset11_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset11_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 42 sequences
# Root sequence: naive
# Abundance range: 1 to 119234
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset11_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset11_1_200_AA.nk.csv
# Done: LLC_dataset11_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset12_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset12_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 75 sequences
# Root sequence: naive
# Abundance range: 1 to 90811
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset12_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset12_1_200_AA.nk.csv
# Done: LLC_dataset12_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset13_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset13_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 69 sequences
# Root sequence: naive
# Abundance range: 1 to 86140
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset13_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset13_1_200_AA.nk.csv
# Done: LLC_dataset13_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset14_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset14_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 67 sequences
# Root sequence: naive
# Abundance range: 1 to 88952
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset14_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset14_1_200_AA.nk.csv
# Done: LLC_dataset14_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset15_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset15_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 115 sequences
# Root sequence: naive
# Abundance range: 1 to 44677
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset15_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset15_1_200_AA.nk.csv
# Done: LLC_dataset15_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset16_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset16_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 90 sequences
# Root sequence: naive
# Abundance range: 1 to 40423
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset16_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset16_1_200_AA.nk.csv
# Done: LLC_dataset16_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset17_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset17_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 70 sequences
# Root sequence: naive
# Abundance range: 1 to 47049
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset17_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset17_1_200_AA.nk.csv
# Done: LLC_dataset17_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset18_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset18_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 10 sequences
# Root sequence: naive
# Abundance range: 1 to 21481
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset18_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset18_1_200_AA.nk.csv
# Done: LLC_dataset18_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset19_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset19_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 69 sequences
# Root sequence: naive
# Abundance range: 1 to 10879
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset19_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset19_1_200_AA.nk.csv
# Done: LLC_dataset19_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset20_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset20_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 108 sequences
# Root sequence: naive
# Abundance range: 1 to 7860
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset20_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset20_1_200_AA.nk.csv
# Done: LLC_dataset20_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset21_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset21_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 52 sequences
# Root sequence: naive
# Abundance range: 1 to 17555
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset21_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset21_1_200_AA.nk.csv
# Done: LLC_dataset21_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset22_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset22_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 60 sequences
# Root sequence: naive
# Abundance range: 1 to 7338
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset22_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset22_1_200_AA.nk.csv
# Done: LLC_dataset22_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset23_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset23_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 90 sequences
# Root sequence: naive
# Abundance range: 1 to 14279
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset23_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset23_1_200_AA.nk.csv
# Done: LLC_dataset23_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset24_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset24_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 52 sequences
# Root sequence: naive
# Abundance range: 1 to 10470
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset24_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset24_1_200_AA.nk.csv
# Done: LLC_dataset24_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset25_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset25_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 35 sequences
# Root sequence: naive
# Abundance range: 1 to 55462
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset25_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset25_1_200_AA.nk.csv
# Done: LLC_dataset25_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset26_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset26_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 73 sequences
# Root sequence: naive
# Abundance range: 1 to 18415
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset26_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset26_1_200_AA.nk.csv
# Done: LLC_dataset26_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset27_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset27_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 40 sequences
# Root sequence: naive
# Abundance range: 1 to 22458
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset27_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset27_1_200_AA.nk.csv
# Done: LLC_dataset27_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset28_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset28_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 27 sequences
# Root sequence: naive
# Abundance range: 1 to 3686
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset28_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset28_1_200_AA.nk.csv
# Done: LLC_dataset28_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset29_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset29_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 35 sequences
# Root sequence: naive
# Abundance range: 1 to 52348
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset29_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset29_1_200_AA.nk.csv
# Done: LLC_dataset29_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset30_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset30_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 8 sequences
# Root sequence: naive
# Abundance range: 1 to 84112
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset30_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset30_1_200_AA.nk.csv
# Done: LLC_dataset30_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset31_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset31_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 81 sequences
# Root sequence: naive
# Abundance range: 1 to 51735
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset31_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset31_1_200_AA.nk.csv
# Done: LLC_dataset31_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset32_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset32_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 5 sequences
# Root sequence: naive
# Abundance range: 1 to 438
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset32_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset32_1_200_AA.nk.csv
# Done: LLC_dataset32_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset33_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset33_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 54 sequences
# Root sequence: naive
# Abundance range: 1 to 4704
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset33_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset33_1_200_AA.nk.csv
# Done: LLC_dataset33_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset34_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset34_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 69 sequences
# Root sequence: naive
# Abundance range: 1 to 53790
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset34_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset34_1_200_AA.nk.csv
# Done: LLC_dataset34_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset35_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset35_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 46 sequences
# Root sequence: naive
# Abundance range: 1 to 110350
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset35_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset35_1_200_AA.nk.csv
# Done: LLC_dataset35_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset36_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset36_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 45 sequences
# Root sequence: naive
# Abundance range: 1 to 42805
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset36_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset36_1_200_AA.nk.csv
# Done: LLC_dataset36_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset37_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset37_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 70 sequences
# Root sequence: naive
# Abundance range: 1 to 52617
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset37_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset37_1_200_AA.nk.csv
# Done: LLC_dataset37_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset38_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset38_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 86 sequences
# Root sequence: naive
# Abundance range: 1 to 82012
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset38_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset38_1_200_AA.nk.csv
# Done: LLC_dataset38_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset39_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset39_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 46 sequences
# Root sequence: naive
# Abundance range: 1 to 11819
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset39_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset39_1_200_AA.nk.csv
# Done: LLC_dataset39_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset40_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset40_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 95 sequences
# Root sequence: naive
# Abundance range: 1 to 26577
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset40_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset40_1_200_AA.nk.csv
# Done: LLC_dataset40_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset41_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset41_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 75 sequences
# Root sequence: naive
# Abundance range: 1 to 27362
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset41_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset41_1_200_AA.nk.csv
# Done: LLC_dataset41_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset42_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset42_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 13 sequences
# Root sequence: naive
# Abundance range: 1 to 371
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset42_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset42_1_200_AA.nk.csv
# Done: LLC_dataset42_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset43_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset43_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 46 sequences
# Root sequence: naive
# Abundance range: 1 to 15214
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset43_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset43_1_200_AA.nk.csv
# Done: LLC_dataset43_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset44_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset44_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 64 sequences
# Root sequence: naive
# Abundance range: 1 to 77438
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset44_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset44_1_200_AA.nk.csv
# Done: LLC_dataset44_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset45_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset45_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 69 sequences
# Root sequence: naive
# Abundance range: 1 to 91195
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset45_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset45_1_200_AA.nk.csv
# Done: LLC_dataset45_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset46_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset46_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 42 sequences
# Root sequence: naive
# Abundance range: 1 to 31756
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset46_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset46_1_200_AA.nk.csv
# Done: LLC_dataset46_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset47_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset47_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 17 sequences
# Root sequence: naive
# Abundance range: 1 to 46172
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset47_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset47_1_200_AA.nk.csv
# Done: LLC_dataset47_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset48_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset48_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 18 sequences
# Root sequence: naive
# Abundance range: 1 to 23783
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset48_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset48_1_200_AA.nk.csv
# Done: LLC_dataset48_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset49_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset49_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 31 sequences
# Root sequence: naive
# Abundance range: 1 to 39399
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset49_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset49_1_200_AA.nk.csv
# Done: LLC_dataset49_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset50_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset50_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 42 sequences
# Root sequence: naive
# Abundance range: 1 to 133414
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset50_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset50_1_200_AA.nk.csv
# Done: LLC_dataset50_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset51_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset51_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 67 sequences
# Root sequence: naive
# Abundance range: 1 to 32012
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset51_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset51_1_200_AA.nk.csv
# Done: LLC_dataset51_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset52_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset52_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 13 sequences
# Root sequence: naive
# Abundance range: 1 to 16045
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset52_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset52_1_200_AA.nk.csv
# Done: LLC_dataset52_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset53_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset53_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 88 sequences
# Root sequence: naive
# Abundance range: 1 to 27965
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset53_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset53_1_200_AA.nk.csv
# Done: LLC_dataset53_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset54_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset54_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 25 sequences
# Root sequence: naive
# Abundance range: 1 to 123105
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset54_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset54_1_200_AA.nk.csv
# Done: LLC_dataset54_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset55_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset55_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 43 sequences
# Root sequence: naive
# Abundance range: 1 to 36831
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset55_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset55_1_200_AA.nk.csv
# Done: LLC_dataset55_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset56_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset56_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 88 sequences
# Root sequence: naive
# Abundance range: 1 to 361303
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset56_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset56_1_200_AA.nk.csv
# Done: LLC_dataset56_1_200_AA.fa
# Running AA-Hamming ClonalTree
# Input FASTA: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset57_1_200_AA.fa
# Output: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset57_1_200_AA.nk
# Settings → useAbundance: True ; revision: True ; trim: True
# Found 96 sequences
# Root sequence: naive
# Abundance range: 1 to 122338
# Building MST tree...
# Trimming tree...
# Revising tree...
# Done!
# Tree saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset57_1_200_AA.nk
# CSV saved to: C:\Users\LEGION\Downloads\AA_Code\New_AA\AA_FASTA\LLC_dataset57_1_200_AA.nk.csv
# Done: LLC_dataset57_1_200_AA.fa
